# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x_axis=[-55, -50,-45,-40,-35,-30,-25, -20, -15, -10, -5, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
y_axis=[1.75, 1.73, 1.70, 1.68, 1.67, 1.67, 1.71, 1.80, 1.95, 2.3, 3.13, 3.137, 2.31, 1.95, 1.79, 1.71, 1.67, 1.67, 1.68, 1.70, 1.73, 1.76]

plt.scatter(x_axis, y_axis, color = 'blue')
plt.axvline(0, color='indigo', linestyle='dotted', label='Asymptote at x=0')
plt.grid(True)
plt.xlabel('Distance from the Center of Mass (cm)')
plt.ylabel('Time Period (T) (s)')
plt.axhline(y=1.705, color='r', linestyle='-')
#plt.axhline(y=1.73, color='b', linestyle='-')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x_axis = [-55, -50, -45, -40, -35, -30, -25, -20, -15, -10, -5, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
y_axis = [1.75, 1.73, 1.70, 1.68, 1.67, 1.67, 1.71, 1.80, 1.95, 2.3, 3.13, 3.137, 2.31, 1.95, 1.79, 1.71, 1.67, 1.67, 1.68, 1.70, 1.73, 1.76]

# Scatter plot
plt.scatter(x_axis, y_axis, color='blue', label='Data points', s= 22)

# Adding vertical asymptote
plt.axvline(0, color='indigo', linestyle='dotted', label='Asymptote at x=0')

# Adding horizontal line and its label in the legend
red_line_y = 1.705
plt.axhline(y=red_line_y, color='maroon', linestyle='-', label=f'T = {red_line_y}')

# Grid and labels
plt.grid(True)
plt.xlabel('Distance from the Center of Mass (cm)')
plt.ylabel('Time Period (T) (s)')

# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x_axis = [-55, -50, -45, -40, -35, -30, -25, -20, -15, -10, -5, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
y_axis = [1.75, 1.73, 1.70, 1.68, 1.67, 1.67, 1.71, 1.80, 1.95, 2.3, 3.13, 3.137, 2.31, 1.95, 1.79, 1.71, 1.67, 1.67, 1.68, 1.70, 1.73, 1.76]

# Scatter plot
plt.scatter(x_axis, y_axis, color='blue', label='Data points', s=22)

# Adding vertical asymptote
plt.axvline(0, color='indigo', linestyle='dotted', label='Asymptote at x=0')

# Adding horizontal lines that intersect exactly 4 points
horizontal_lines = [1.67, 1.70, 1.73]  # y-values chosen to intersect exactly 4 points
colors = ['green', 'purple', 'orange']  # Colors for each line

for y_val, color in zip(horizontal_lines, colors):
    plt.axhline(y=y_val, color=color, linestyle='--', label=f'T = {y_val} ({color})')

# Adding the original red horizontal line
red_line_y = 1.705
plt.axhline(y=red_line_y, color='maroon', linestyle='-', label=f'T = {red_line_y} (maroon)')

# Grid and labels
plt.grid(True)
plt.xlabel('Distance from the Center of Mass (cm)')
plt.ylabel('Time Period (T) (s)')

# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x_axis = [-55, -50, -45, -40, -35, -30, -25, -20, -15, -10, -5, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
y_axis = [1.75, 1.73, 1.70, 1.68, 1.67, 1.67, 1.71, 1.80, 1.95, 2.3, 3.13, 3.137, 2.31, 1.95, 1.79, 1.71, 1.67, 1.67, 1.68, 1.70, 1.73, 1.76]

# Scatter plot
plt.scatter(x_axis, y_axis, color='blue', label='Data points', s=26)

# Adding vertical asymptote
plt.axvline(0, color='indigo', linestyle='dotted', label='Asymptote at x=0')

# Adding horizontal lines that intersect exactly 4 points
horizontal_lines = [1.67, 1.69, 1.73]  # y-values chosen to intersect exactly 4 points
colors = ['green', 'purple', 'orange']  # Colors for each line

for y_val, color in zip(horizontal_lines, colors):
    plt.axhline(y=y_val, color=color, linestyle='--', label=f'T = {y_val} ')

# Adding the original red horizontal line
red_line_y = 1.705
plt.axhline(y=red_line_y, color='maroon', linestyle='-', label=f'T = {red_line_y} ')

# Grid and labels
plt.grid(True)
plt.xlabel('Distance from the Center of Mass (cm)')
plt.ylabel('Time Period (T) (s)')

# Setting y-axis limit
plt.ylim(1.6, 2.0)

# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Data
x_axis = [-55, -50, -45, -40, -35, -30, -25, -20, -15, -10, -5, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
y_axis = [1.75, 1.73, 1.70, 1.68, 1.67, 1.67, 1.71, 1.80, 1.95, 2.3, 3.13, 3.137, 2.31, 1.95, 1.79, 1.71, 1.67, 1.67, 1.68, 1.70, 1.73, 1.76]

# Error values
x_error = [0.1] * len(x_axis)  # Constant error of 0.01 cm for all x-axis values
y_error = [0.0349] * len(y_axis)  # Constant error of 0.0349 s for all y-axis values

# Scatter plot with error bars
plt.errorbar(x_axis, y_axis, xerr=x_error, yerr=y_error, fmt='o', color='blue',markersize=5, capsize=3)

# Adding vertical asymptote
plt.axvline(0, color='indigo', linestyle='dotted', label='Asymptote')

# Adding horizontal lines that intersect exactly 4 points
horizontal_lines = [1.67, 1.69, 1.73]  # y-values chosen to intersect exactly 4 points
colors = ['green', 'purple', 'orange']  # Colors for each line

for y_val, color in zip(horizontal_lines, colors):
    plt.axhline(y=y_val, color=color, linestyle='--', label=f'T = {y_val} ')

# Adding the original red horizontal line
red_line_y = 1.705
plt.axhline(y=red_line_y, color='maroon', linestyle='-', label=f'T = {red_line_y} ')

# Grid and labels
plt.grid(True)
plt.xlabel('Distance from the Center of Mass (cm)')
plt.ylabel('Time Period (T) (s)')

# Setting y-axis limit
plt.ylim(1.6, 2.0)

# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Data
x_axis = [-55, -50, -45, -40, -35, -30, -25, -20, -15, -10, -5, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
y_axis = [1.75, 1.73, 1.70, 1.68, 1.67, 1.67, 1.71, 1.80, 1.95, 2.3, 3.13, 3.137, 2.31, 1.95, 1.79, 1.71, 1.67, 1.67, 1.68, 1.70, 1.73, 1.76]

# Error values
x_error = [0.1] * len(x_axis)  # Constant error of 0.01 cm for all x-axis values
y_error = [0.0349] * len(y_axis)  # Constant error of 0.0349 s for all y-axis values

# Scatter plot with error bars
plt.errorbar(x_axis, y_axis, xerr=x_error, yerr=y_error, fmt='o', color='blue', label='Data points', markersize=5, capsize=3)

# Adding vertical asymptote
plt.axvline(0, color='indigo', linestyle='dotted', label='Asymptote at x=0')

# Adding horizontal line and its label in the legend
red_line_y = 1.705
plt.axhline(y=red_line_y, color='maroon', linestyle='-', label=f'T = {red_line_y}')

# Grid and labels
plt.grid(True)
plt.xlabel('Distance from the Center of Mass (cm)')
plt.ylabel('Time Period (T) (s)')

# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Data
x_axis = [-55, -50, -45, -40, -35, -30, -25, -20, -15, -10, -5, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
y_axis = [1.75, 1.73, 1.70, 1.68, 1.67, 1.67, 1.71, 1.80, 1.95, 2.3, 3.13, 3.137, 2.31, 1.95, 1.79, 1.71, 1.67, 1.67, 1.68, 1.70, 1.73, 1.76]

# Error values
x_error = [0.1] * len(x_axis)  # Constant error of 0.01 cm for all x-axis values
y_error = [0.0349] * len(y_axis)  # Constant error of 0.0349 s for all y-axis values

# Scatter plot with error bars
plt.errorbar(x_axis, y_axis, xerr=x_error, yerr=y_error, fmt='o', color='indigo',markersize=5, capsize=3)

# Adding vertical asymptote
#plt.axvline(0, color='indigo', linestyle='dotted', label='Asymptote')

# Adding horizontal lines that intersect exactly 4 points
horizontal_lines = [1.67, 1.69, 1.73]  # y-values chosen to intersect exactly 4 points
colors = ['green', 'purple', 'orange']  # Colors for each line

for y_val, color in zip(horizontal_lines, colors):
    plt.axhline(y=y_val, color=color, linestyle='--', label=f'T = {y_val} ')

# Adding the original red horizontal line
red_line_y = 1.705
plt.axhline(y=red_line_y, color='maroon', linestyle='-', label=f'T = {red_line_y} ')

# Grid and labels
plt.grid(True)
plt.xlabel('Distance from the Center of Mass (cm)')
plt.ylabel('Time Period (T) (s)')

# Setting y-axis limit
plt.ylim(1.6, 2.0)
plt.xlim(-21,-19)
# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Data
x_axis = [-55, -50, -45, -40, -35, -30, -25, -20, -15, -10, -5, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
y_axis = [1.75, 1.73, 1.70, 1.68, 1.67, 1.67, 1.71, 1.80, 1.95, 2.3, 3.13, 3.137, 2.31, 1.95, 1.79, 1.71, 1.67, 1.67, 1.68, 1.70, 1.73, 1.76]

# Error values
x_error = [0.1] * len(x_axis)  # Constant error of 0.01 cm for all x-axis values
y_error = [0.0349] * len(y_axis)  # Constant error of 0.0349 s for all y-axis values

# Scatter plot with error bars
plt.errorbar(x_axis, y_axis, xerr=x_error, yerr=y_error, fmt='o', color='blue', label='Data points', markersize=5, capsize=3)

# Adding vertical asymptote
plt.axvline(0, color='indigo', linestyle='dotted', label='Asymptote at x=0')

# Adding horizontal line and its label in the legend
red_line_y = 1.705
plt.axhline(y=red_line_y, color='maroon', linestyle='-', label=f'T = {red_line_y}')

# vertical lines
plt.axvline(x=-45,color='green',linewidth=1)
plt.text(-42.8,2.6,'l=-45 cm')

plt.axvline(x=-25,color='green',linewidth=1)
plt.text(-23.0,2.6,'l=-25 cm')

plt.axvline(x=25,color='green',linewidth=1)
plt.text(7.0,2.6,'l=25 cm')

plt.axvline(x=45,color='green',linewidth=1)
plt.text(27.8,2.6,'l=45 cm')


# Grid and labels
plt.grid(True)
plt.xlabel('Distance from the Center of Mass (cm)')
plt.ylabel('Time Period (T) (s)')

# Display legend
plt.legend()

# Show the plot
plt.show()
